# %%
from src.utils.device import print_device_info

print_device_info()
# Out:
# Torch version: 2.11.0+cu128
# CUDA available: True
# GPU: NVIDIA GeForce RTX 5070 Ti

# %%
from src.utils.gpu_monitor import (
    gpu_memory_summary,
)

gpu_memory_summary()
# Out:
# {'cuda_available': True, 'allocated_gb': 0.0, 'reserved_gb': 0.0}
