# %%
from pathlib import Path

from src.data.local_image_loader import load_local_image

image_dir = Path("data/samples/fashion_images")

image_paths = list(image_dir.glob("*.jpg"))

print(image_paths)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from pathlib import Path
#       2
# ----> 3 from src.data.local_image_loader import load_local_image
#       4
#       5 image_dir = Path("data/samples/fashion_images")
#       6
#
# ModuleNotFoundError: No module named 'src'

# %%
from src.models.qwen2vl_loader import load_qwen2vl
from src.models.batch_inference import run_batch_inference

model, processor = load_qwen2vl()

results = run_batch_inference(
    model=model,
    processor=processor,
    image_paths=image_paths,
    image_loader=load_local_image,
    prompt="Describe this fashion outfit professionally.",
)

results
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.models.qwen2vl_loader import load_qwen2vl
#       2 from src.models.batch_inference import run_batch_inference
#       3
#       4 model, processor = load_qwen2vl()
#
# ModuleNotFoundError: No module named 'src'

# %%
from src.utils.experiment_logger import save_experiment

saved_path = save_experiment(
    results=results,
    experiment_name="fashion_batch_test",
)

print(saved_path)
