# %%
from src.models.qwen2vl_loader import load_qwen2vl
from src.models.model_stats import count_parameters

model, processor = load_qwen2vl()

count_parameters(model)

# %%
from src.training.training_summary import (
    print_training_summary,
)

stats = count_parameters(model)

print_training_summary(stats)

# %%
from src.utils.experiment_registry import (
    create_experiment_id,
)

create_experiment_id()
